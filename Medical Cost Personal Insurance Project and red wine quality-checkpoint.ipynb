# %% [markdown]
# # RED WINE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\dg239\Downloads\winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
#Description
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
sns.countplot(df['quality'])
plt.show()

# %%
sns.countplot(df['pH'])
plt.show()

# %%
sns.countplot(df['alcohol'])
plt.show()

# %%
sns.countplot(df['fixed acidity'])
plt.show()

# %%
sns.countplot(df['volatile acidity'])
plt.show()

# %%
sns.countplot(df['citric acid'])
plt.show()

# %%
sns.countplot(df['density'])
plt.show()

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
#checking for outliers
plt.figure(figsize=(25,20),facecolor="white")
p=1
for i in df.columns:
    if p<=13:
        plt.subplot(5,11,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()

# %%
plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1
for column in df:
    if plotnumber<=18:
        ax=plt.subplot(6,4,plotnumber)
    sns.distplot(df[column],color='b')
    plt.xlabel(column,fontsize=20)
    plotnumber+=1
    plt.show()

# %%
from scipy.stats import zscore

# %%
out_features=df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]
z=np.abs(zscore(out_features))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
df['residual sugar']=np.cbrt(df['residual sugar'])

# %%
cor=df.corr()
cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.156909          0.017826     0.165255
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,fmt="0.1g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
sns.pairplot(df)

# %%
# Create Classification version of target variable
df['goodquality'] = [1 if x >= 7 else 0 for x in df['quality']]# Separate feature variables and target variable
X = df.drop(['quality','goodquality'], axis = 1)
Y = df['goodquality']

# %%
df['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00        1.238562      0.076
# 1               7.8             0.880         0.00        1.375069      0.098
# 2               7.8             0.760         0.04        1.320006      0.092
# 3              11.2             0.280         0.56        1.238562      0.075
# 4               7.4             0.700         0.00        1.238562      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08        1.259921      0.090
# 1595            5.9             0.550         0.10        1.300591      0.062
# 1596            6.3             0.510         0.13        1.320006      0.076
# 1597            5.9             0.645         0.12        1.259921      0.075
# 1598            6.0             0.310         0.47        1.532619      0.067
#
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: goodquality, Length: 1599, dtype: int64

# %%
#Features scaling using standard scalarization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877    -1.391472       -0.552402  -0.243707
# 1         -0.298547          1.967442    -1.391472        0.207150   0.223875
# 2         -0.298547          1.297065    -1.186070       -0.099231   0.096353
# 3          1.654856         -1.384443     1.484154       -0.552402  -0.264960
# 4         -0.528360          0.961877    -1.391472       -0.552402  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -0.980669       -0.433557   0.053845
# 1595      -1.390155          0.123905    -0.877968       -0.207258  -0.541259
# 1596      -1.160343         -0.099554    -0.723916       -0.099231  -0.243707
# 1597      -1.390155          0.654620    -0.775267       -0.433557  -0.264960
# 1598      -1.332702         -1.216849     1.021999        1.083792  -0.434990
#
# ...

# %%
#finding Varience inflation factor in each scaled column i.e., x.shape[1] (1/(1-R2))
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#     VIF Values              Features
# 0     7.984270         fixed acidity
# 1     1.788367      volatile acidity
# 2     3.127763           citric acid
# 3     1.947078        residual sugar
# 4     1.482299             chlorides
# 5     1.950061   free sulfur dioxide
# 6     2.195032  total sulfur dioxide
# 7     7.077538               density
# 8     3.381543                    pH
# 9     1.442338             sulphates
# 10    3.366317               alcohol

# %%
Y.value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x1,Y1= SM.fit_resample(X,Y)

# %%
Y.value_counts()
Y1.value_counts()
# Out:
# 0    1382
# 1    1382
# Name: goodquality, dtype: int64

# %%
#Finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc= accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
    print("Best Accuracy is ",maxAccu,"at random_state",maxRS)
# Out:
# Best Accuracy is  0.9166666666666666 at random_state 1
# Best Accuracy is  0.9166666666666666 at random_state 1
# Best Accuracy is  0.9208333333333333 at random_state 3
# Best Accuracy is  0.9208333333333333 at random_state 3
# Best Accuracy is  0.9208333333333333 at random_state 3
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# Best Accuracy is  0.9270833333333334 at random_state 6
# ...

# %%
#Creating train test split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# RandomForestClassifer
# Checking accuracy for RandomForestClassifier
RFC= RandomForestClassifier()
RFC.fit(X_train,Y_train)
predRFC= RFC.predict(X_test)
print(accuracy_score(Y_test,predRFC))
print(confusion_matrix(Y_test,predRFC))
print(classification_report(Y_test,predRFC))
# Out:
# 0.9270833333333334
# [[415  12]
#  [ 23  30]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       427
#            1       0.71      0.57      0.63        53
#
#     accuracy                           0.93       480
#    macro avg       0.83      0.77      0.80       480
# weighted avg       0.92      0.93      0.92       480

# %%
# Gradient Boosting Classifier
GB= GradientBoostingClassifier()
GB.fit(X_train,Y_train)
predGB= GB.predict(X_test)
print(accuracy_score(Y_test,predGB))
print(confusion_matrix(Y_test,predGB))
print(classification_report(Y_test,predGB))
# Out:
# 0.9083333333333333
# [[409  18]
#  [ 26  27]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       427
#            1       0.60      0.51      0.55        53
#
#     accuracy                           0.91       480
#    macro avg       0.77      0.73      0.75       480
# weighted avg       0.90      0.91      0.91       480

# %%
#Logistic Regression
LR= LogisticRegression()
LR.fit(X_train,Y_train)
predLR= LR.predict(X_test)
print(accuracy_score(Y_test,predLR))
print(confusion_matrix(Y_test,predLR))
print(classification_report(Y_test,predLR))
# Out:
# 0.9041666666666667
# [[410  17]
#  [ 29  24]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       427
#            1       0.59      0.45      0.51        53
#
#     accuracy                           0.90       480
#    macro avg       0.76      0.71      0.73       480
# weighted avg       0.90      0.90      0.90       480

# %%
#Bagging Classifier
BC= BaggingClassifier()
BC.fit(X_train,Y_train)
predBC= BC.predict(X_test)
print(accuracy_score(Y_test,predBC))
print(confusion_matrix(Y_test,predBC))
print(classification_report(Y_test,predBC))
# Out:
# 0.925
# [[412  15]
#  [ 21  32]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       427
#            1       0.68      0.60      0.64        53
#
#     accuracy                           0.93       480
#    macro avg       0.82      0.78      0.80       480
# weighted avg       0.92      0.93      0.92       480

# %%
#ExtraTreesClassifier
ET= ExtraTreesClassifier()
ET.fit(X_train,Y_train)
predET= ET.predict(X_test)
print(accuracy_score(Y_test,predET))
print(confusion_matrix(Y_test,predET))
print(classification_report(Y_test,predET))
# Out:
# 0.9208333333333333
# [[415  12]
#  [ 26  27]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       427
#            1       0.69      0.51      0.59        53
#
#     accuracy                           0.92       480
#    macro avg       0.82      0.74      0.77       480
# weighted avg       0.91      0.92      0.92       480

# %%
from sklearn.tree import DecisionTreeClassifier
#DecisionTreesClassifier
DTC= DecisionTreeClassifier()
DTC.fit(X_train,Y_train)
predDTC= DTC.predict(X_test)
print(accuracy_score(Y_test,predDTC))
print(confusion_matrix(Y_test,predDTC))
print(classification_report(Y_test,predDTC))
# Out:
# 0.88125
# [[394  33]
#  [ 24  29]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       427
#            1       0.47      0.55      0.50        53
#
#     accuracy                           0.88       480
#    macro avg       0.71      0.73      0.72       480
# weighted avg       0.89      0.88      0.89       480

# %%
# Cross Validation Score
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(RFC,X,Y)
print(score)
print(score.mean())
print("Differnce between Accuracy score and Cross Validation Score is- ",accuracy_score(Y_test,predRFC)-score.mean())
# Out:
# [0.875      0.85       0.875      0.840625   0.88087774]
# 0.8643005485893417
# Differnce between Accuracy score and Cross Validation Score is-  0.06278278474399168

# %%
#  Checking CV score for Logistic Regression
score= cross_val_score(LR,X,Y)
print(score)
print(score.mean())
print("Difference between Acccuracy Score and Cross Validation Score is- ",accuracy_score(Y_test,predLR)-score.mean())
# Out:
# [0.865625   0.8625     0.89375    0.85       0.88401254]
# 0.8711775078369908
# Difference between Acccuracy Score and Cross Validation Score is-  0.0329891588296759

# %%
#  Checking CV score for Bagging Classifier
score= cross_val_score(BC,X,Y)
print(score)
print(score.mean())
print("Difference between Acccuracy Score and Cross Validation Score is- ",accuracy_score(Y_test,predBC)-score.mean())
# Out:
# [0.890625   0.825      0.86875    0.821875   0.87147335]
# 0.8555446708463951
# Difference between Acccuracy Score and Cross Validation Score is-  0.06945532915360497

# %%
#  Checking CV score for ExtraTress Classifier
score= cross_val_score(ET,X,Y)
print(score)
print(score.mean())
print("Difference between Acccuracy Score and Cross Validation Score is- ",accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.878125   0.859375   0.878125   0.85625    0.88401254]
# 0.8711775078369906
# Difference between Acccuracy Score and Cross Validation Score is-  -0.08367750783699057

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion': ['gini','entropy'],
           'random_state':[10,50,1000],
           'max_depth':[0,10,20],
           'n_jobs':[-2,-1,1],
           'n_estimators':[50,100,200,300]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
GCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
Final_model=ExtraTreesClassifier(criterion='gini',max_depth=20,n_estimators=200,n_jobs=-2,random_state=10)
Final_model.fit(X_test,Y_test)
pred=Final_model.predict(X_test)
acc= accuracy_score(Y_test,pred)
print(acc*100)
# Out:
# 100.0

# %%
plt.title("ROC for the best model")
plt.show()

# %%
from sklearn import metrics
from sklearn import datasets
from sklearn import model_selection

# %%
from sklearn import metrics
fpr, tpr, thresholds= metrics.roc_curve(Y_test,pred)
roc_auc= metrics.auc(fpr,tpr)
display= metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=Final_model)
display.plot()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
auc_score = roc_auc_score(Y_test, Final_model.predict(X_test))

# %%
y_pred_prob = Final_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(Y_test,y_pred_prob)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr, label='ExtraTreesClassifier')
plt.xlabel('False postive rate')
plt.ylabel('True postive rate')
plt.show()
auc_score = roc_auc_score(Y_test, Final_model.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  1.0

# %%
import joblib
joblib.dump(Final_model,'Red_Wine_Quality_Final.pkl')
# Out:
# ['Red_Wine_Quality_Final.pkl']

# %%
#predicting the saved model
model=joblib.load("Red_Wine_Quality_Final.pkl")

# %%
#prediction
prediction=model.predict(x_test)

# %%
a=np.array(y_test)
df=pd.DataFrame()
df["Predicted"]=prediction
df["Original"]=a
df
# Out:
#      Predicted  Original
# 0            0         0
# 1            0         0
# 2            0         0
# 3            1         0
# 4            0         0
# ..         ...       ...
# 475          0         0
# 476          0         0
# 477          0         0
# 478          0         0
# 479          0         0
#
# [480 rows x 2 columns]

# %% [markdown]
# # Medical Cost Personal Insurance Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\dg239\Downloads\medical_cost_insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
print(f"The rows and columns in the dataset:{df.shape}")
print(f"\n The column headers in the dataset:{df.columns}")
# Out:
# The rows and columns in the dataset:(1338, 7)
#
#  The column headers in the dataset:Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# It gives brief about the dataset which includes indexing type, columntype,no null values and memory usage is 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Let's visualize it using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null values

# %%
df['region'].value_counts().sort_values()
# Out:
# northeast    324
# southwest    325
# northwest    325
# southeast    364
# Name: region, dtype: int64

# %%
df['children'].value_counts().sort_values()
# Out:
# 5     18
# 4     25
# 3    157
# 2    240
# 1    324
# 0    574
# Name: children, dtype: int64

# %%
#converting categorical to numerical
clean_df = {'sex': {'male' : 0 , 'female' : 1} ,
                 'smoker': {'no': 0 , 'yes' : 1},
                   'region' : {'northwest':0, 'northeast':1,'southeast':2,'southwest':3}
               }
df_copy = df.copy()
df_copy.replace(clean_df, inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
df_copy.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.514948  13270.422265
# std       1.105572  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
df_copy.nunique().to_frame("No. of unique values")
# Out:
#           No. of unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %%
#checking the value counts of each column
for i in df_copy.columns:
    print(df_copy[i].value_counts())
print("\n")
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
# 0    676
# 1    662
# Name: sex, dtype: int64
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
# 0    1064
# 1     274
# Name: smoker, dtype: int64
# 2    364
# 3    325
# 0    325
# 1    324
# ...

# %%
df_copy.duplicated().sum()
# Out:
# 1

# %%
df_copy.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.037853
# charges     1.515880
# dtype: float64

# %%
cor=df_copy.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.109272  0.042469 -0.025019  0.003243  0.299008
# sex       0.020856  1.000000 -0.046371 -0.017163 -0.076185 -0.007974 -0.057292
# bmi       0.109272 -0.046371  1.000000  0.012759  0.003750  0.156686  0.198341
# children  0.042469 -0.017163  0.012759  1.000000  0.007673 -0.001907  0.067998
# smoker   -0.025019 -0.076185  0.003750  0.007673  1.000000  0.013246  0.787251
# region    0.003243 -0.007974  0.156686 -0.001907  0.013246  1.000000  0.011741
# charges   0.299008 -0.057292  0.198341  0.067998  0.787251  0.011741  1.000000

# %%
sns.heatmap(df_copy.corr(),linewidth=0.1,fmt="0.1g",linecolor='black',annot=True,cmap="Blues_r")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,10))
plt.title('Age VS Charges')
sns.barplot(x='age',y='charges',data=df_copy,palette='BuPu')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('Region VS Charges')
sns.barplot(x='region',y='charges',data=df_copy,palette='BuPu')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('Smoker VS Charges')
sns.barplot(x='smoker',y='charges',data=df_copy,palette='BuPu',hue='sex')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('sex VS Charges')
sns.barplot(x='sex',y='charges',data=df_copy,palette='BuPu')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('Age VS Charges')
sns.scatterplot(x='age',y='charges',data=df_copy,palette='BuPu')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('Bmi VS Charges')
sns.scatterplot(x='bmi',y='charges',data=df_copy,palette='BuPu')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title('AGE')
sns.distplot(df_copy['age'])
plt.xlabel('age')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title('BMI')
sns.distplot(df_copy['bmi'])
plt.xlabel('bmi')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title('Charges')
sns.distplot(df_copy['charges'])
plt.xlabel('charges')
plt.ylabel('count')
plt.show()

# %%
print('Printing Skewness for all columns')
print()
for col in list(df_copy.columns):
    print('{0} : Skewness {1:.3f}'.format(col,df_copy[col].skew()))
# Out:
# Printing Skewness for all columns
#
# age : Skewness 0.056
# sex : Skewness 0.021
# bmi : Skewness 0.284
# children : Skewness 0.938
# smoker : Skewness 1.465
# region : Skewness -0.038
# charges : Skewness 1.516

# %%
plt.figure(figsize=(20,25))
p=1
for i in df_copy:
    if p<=13:
        plt.subplot(5,4,p)
        sns.boxplot(df_copy[i],palette="BuPu")
        plt.xlabel(i)
p+=1
plt.show()

# %%
from scipy.stats import zscore

# %%
out_features=df_copy[['charges','age','sex','bmi','children','smoker','region']]
z=np.abs(zscore(out_features))
z
# Out:
#        charges       age       sex       bmi  children    smoker    region
# 0     0.298584  1.438764  1.010519  0.453320  0.908614  1.970587  1.343746
# 1     0.953689  1.509965  0.989591  0.509621  0.078767  0.507463  0.438898
# 2     0.728675  0.797954  0.989591  0.383307  1.580926  0.507463  0.438898
# 3     0.719843  0.441948  0.989591  1.305531  0.908614  0.507463  1.370796
# 4     0.776802  0.513149  0.989591  0.292556  0.908614  0.507463  1.370796
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.220551  0.768473  0.989591  0.050297  1.580926  0.507463  1.370796
# 1334  0.914002  1.509965  1.010519  0.206139  0.908614  0.507463  0.465949
# 1335  0.961596  1.509965  1.010519  1.014878  0.908614  0.507463  0.438898
# 1336  0.930362  1.296362  1.010519  0.797813  0.908614  0.507463  1.343746
# 1337  1.311053  1.551686  1.010519  0.261388  0.908614  1.970587  1.370796
#
# [1338 rows x 7 columns]

# %%
#threshold=3
np.where(z>3)
# Out:
# (array([  32,   34,   71,  116,  166,  413,  425,  438,  543,  568,  577,
#          640,  819,  847,  877,  932,  937,  969,  984, 1047, 1085, 1116,
#         1130, 1146, 1230, 1245, 1272, 1300, 1317], dtype=int64),
#  array([4, 0, 4, 3, 4, 4, 4, 4, 0, 4, 0, 4, 0, 3, 4, 4, 4, 4, 4, 3, 4, 4,
#         4, 0, 0, 4, 4, 0, 3], dtype=int64))

# %%
z.iloc[166,4]
# Out:
# 3.240618711442044

# %%
df1=df_copy[(z<3).all(axis=1)]
df.shape
# Out:
# (1338, 7)

# %%
"""
x=has independent variables
y= target variable
z=np.abs(zscore(x))
x1=x[(z<3).all(axis=1)]
y1=y[(z<3).all(axis=1)]
"""
# Out:
# '\nx=has independent variables\ny= target variable\nz=np.abs(zscore(x))\nx1=x[(z<3).all(axis=1)]\ny1=y[(z<3).all(axis=1)]\n'

# %%
#Shape of Old and New DataFrame
print("Old DataFrame- ",df_copy.shape[0])
print("New DataFrame- ",df1.shape[0])
# Out:
# Old DataFrame-  1338
# New DataFrame-  1309

# %%
print("Data Loss Percentage- ",(df_copy.shape[0]-df1.shape[0])/df_copy.shape[0]*100)
# Out:
# Data Loss Percentage-  2.167414050822123

# %%
#IQR Method
#1st Quantile
Q1=out_features.quantile(0.25)

# %%
#3rd quantile
Q3=out_features.quantile(0.75)

# %%
#IQR
IQR=Q3-Q1
df2=df_copy[~((df_copy<(Q1-1.5*IQR))|(df_copy>(Q3+1.5*IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (1055, 7)

# %%
print("Data Loss Percentage After removing outliers with IQR method- ",((df_copy.shape[0]-df2.shape[0]/df_copy.shape[0]*100)))
# Out:
# Data Loss Percentage After removing outliers with IQR method-  1259.150971599402

# %%
plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1
for column in df_copy:
    if plotnumber<=18:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df_copy[column],color='b')
        plt.xlabel(column,fontsize=20)
plotnumber+=1
plt.show()

# %%
#Checking for skewness
df_copy.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.037853
# charges     1.515880
# dtype: float64

# %%
df_copy['smoker']=np.cbrt(df_copy['smoker'])

# %%
df_copy['charges']=np.cbrt(df_copy['charges'])

# %%
#Lets Visualize how the data has beeen distributed in charges after removing skewness
sns.distplot(df_copy['charges'],color="m",kde_kws={"shade":True},hist=False)
plt.show()

# %%
#Lets Visualize again
plt.figure(figsize=(20,25),facecolor='red')
plotnumber=1
for column in df_copy:
    if plotnumber<=13:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df_copy[column],color='green')
        plt.xlabel(column,fontsize=20)
plotnumber+=1
plt.show()

# %%
df_copy.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.109272  0.042469 -0.025019  0.003243  0.451354
# sex       0.020856  1.000000 -0.046371 -0.017163 -0.076185 -0.007974 -0.027560
# bmi       0.109272 -0.046371  1.000000  0.012759  0.003750  0.156686  0.156375
# children  0.042469 -0.017163  0.012759  1.000000  0.007673 -0.001907  0.123941
# smoker   -0.025019 -0.076185  0.003750  0.007673  1.000000  0.013246  0.732564
# region    0.003243 -0.007974  0.156686 -0.001907  0.013246  1.000000 -0.007338
# charges   0.451354 -0.027560  0.156375  0.123941  0.732564 -0.007338  1.000000

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df_copy.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Blues_r')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Feature',fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %%
df_copy.corr().charges.sort_values()
# Out:
# sex        -0.027560
# region     -0.007338
# children    0.123941
# bmi         0.156375
# age         0.451354
# smoker      0.732564
# charges     1.000000
# Name: charges, dtype: float64

# %%
plt.figure(figsize=(22,7))
df_copy.corr()['charges'].sort_values(ascending=False).drop(['charges']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('Correlation Using Barplot',fontsize=20)
plt.show()

# %%
#separating features and label
#separating the independent and target variables into x and y
x=df1.drop("charges",axis=1)
y=df1["charges"]
print("Feature Dimensions- ",x.shape)
print("Label Dimensions- ",y.shape)
# Out:
# Feature Dimensions-  (1309, 6)
# Label Dimensions-  (1309,)

# %%
#Feature scaling using Standard Scalarization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.439063  1.005362 -0.449359 -0.929616  1.984848  1.352435
# 1    -1.510086 -0.994667  0.533391 -0.040093 -0.503817  0.448279
# 2    -0.799859 -0.994667  0.404478  1.738954 -0.503817  0.448279
# 3    -0.444746 -0.994667 -1.319101 -0.929616 -0.503817 -1.360033
# 4    -0.515769 -0.994667 -0.285288 -0.929616 -0.503817 -1.360033
# ...        ...       ...       ...       ...       ...       ...
# 1304  0.762639 -0.994667  0.064617  1.738954 -0.503817 -1.360033
# 1305 -1.510086  1.005362  0.223666 -0.929616 -0.503817 -0.455877
# 1306 -1.510086  1.005362  1.049041 -0.929616 -0.503817  0.448279
# 1307 -1.297018  1.005362 -0.800939 -0.929616 -0.503817  1.352435
# 1308  1.543888  1.005362 -0.253479 -0.929616  1.984848 -1.360033
#
# [1309 rows x 6 columns]

# %%
#Checking Variance Inflation Factor(VIF)
#Finding Varience Inflation Factor in each scaled column i.e. xshape[1](1/1-R2)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF Values  Features
# 0    1.018939       age
# 1    1.008812       sex
# 2    1.043533       bmi
# 3    1.006189  children
# 4    1.008245    smoker
# 5    1.027410    region

# %%
#Finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#Creating Train Test Split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
    print("Maximum r2_score is ",maxAccu,"on Random_state",maxRS)
# Out:
# Maximum r2_score is  0.7209729949282813 on Random_state 1
# Maximum r2_score is  0.735041633140614 on Random_state 2
# Maximum r2_score is  0.7401792369024554 on Random_state 3
# Maximum r2_score is  0.7427119394936457 on Random_state 4
# Maximum r2_score is  0.7427119394936457 on Random_state 4
# Maximum r2_score is  0.7427119394936457 on Random_state 4
# Maximum r2_score is  0.7427119394936457 on Random_state 4
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# Maximum r2_score is  0.7696929016096968 on Random_state 8
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.8156310026987059
# R2_score on trainingData: 72.35259925467584
# Mean Absolute Error:- 3789.4462116891673
# Mean Squared Error:- 25850586.821152564
# Root Mean Squared Error:-  5084.347236484991

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Linear Regression",fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9016780733584236
# R2_score on trainingData: 97.25339788507156
# Mean Absolute Error:- 2229.4995966353704
# Mean Squared Error:- 13785829.170169389
# Root Mean Squared Error:-  3712.9273047245874

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: 0.8756249708313883
# R2_score on trainingData: 84.19349837874329
# Mean Absolute Error:- 2716.2872868320615
# Mean Squared Error:- 17438764.30944829
# Root Mean Squared Error:-  4175.97465383212

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score: 0.9192023406663036
# R2_score on trainingData: 88.32734045300877
# Mean Absolute Error:- 2081.2557404019667
# Mean Squared Error:- 11328731.718046645
# Root Mean Squared Error:-  3365.8181350225454

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_ridge=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ridge))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_ridge))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_ridge))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_score: 0.815547167346558
# R2_score on trainingData: 72.352509273608
# Mean Absolute Error:- 3791.295951721838
# Mean Squared Error:- 25862341.471235294
# Root Mean Squared Error:-  5085.503069631882

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: 0.7033593277201673
# R2_score on trainingData: 100.0
# Mean Absolute Error:- 3000.910729259542
# Mean Squared Error:- 41592326.072714694
# Root Mean Squared Error:-  6449.211275242476

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on trainingData:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_ETR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_ETR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: 0.8811546154254177
# R2_score on trainingData: 100.0
# Mean Absolute Error:- 2185.6364664880425
# Mean Squared Error:- 16663446.551254522
# Root Mean Squared Error:-  4082.0885036038258

# %%
#Cross Validation Score
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.7635024  0.71276209 0.77975501 0.7293182  0.76646159]
# 0.7503598582660594
# Difference between R2score and Cross Validation is-  6.527114443264647

# %%
score1=cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [0.85357267 0.78845344 0.86160763 0.8313443  0.85164685]
# 0.8373249773199957
# Difference between R2score and Cross Validation is-  6.435309603842798

# %%
score2=cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_knn)-score2.mean())*100)
# Out:
# [0.82703083 0.77380626 0.83345689 0.79789805 0.8231008 ]
# 0.811058563054363
# Difference between R2score and Cross Validation is-  6.456640777702538

# %%
score3=cross_val_score(GBR,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [0.87477855 0.80653591 0.87837205 0.84873166 0.86243484]
# 0.8541706013270645
# Difference between R2score and Cross Validation is-  6.503173933923911

# %%
score4=cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_ridge)-score4.mean())*100)
# Out:
# [0.76348224 0.71281639 0.77966347 0.72938683 0.76646021]
# 0.7503618294198091
# Difference between R2score and Cross Validation is-  6.518533792674885

# %%
score5=cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_dtr)-score5.mean())*100)
# Out:
# [0.77683877 0.61507567 0.69198972 0.73830048 0.69478248]
# 0.7033974255220435
# Difference between R2score and Cross Validation is-  -0.0038097801876246784

# %%
score6=cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between R2score and Cross Validation is- ",(r2_score(y_test,pred_ETR)-score6.mean())*100)
# Out:
# [0.83438964 0.75297967 0.83509693 0.81361942 0.84262544]
# 0.8157422207684576
# Difference between R2score and Cross Validation is-  6.541239465696014

# %%
from sklearn.model_selection import GridSearchCV

# %%
param= {'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],'solver':['auto','svd','cholesky','lsqr','sag','saga','lbfgs'],'positive':[False,True],'random_state':[1,4,10,20]}

# %%
gscv= GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 20,
#  'solver': 'sag'}

# %%
Model=Ridge(alpha=2,fit_intercept=True,positive=False,random_state=20,solver='sag')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred))
print('Mean Squared Error:-',mean_squared_error(y_test,pred))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8154693546180419
# Mean Absolute Error:- 3793.008799531494
# Mean Squared Error:- 25873251.682408202
# Root Mean Squared Error:-  5086.575634197156

# %%
import joblib

# %%
import pickle

# %%
filename='Medical_cost'
pickle.dump(Model,open('Medical_cost','wb'))

# %%
import pickle
loaded_model=pickle.load(open('Medical_cost','rb'))
result=loaded_model.score(x_test,y_test)

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                     0            1             2             3    \
# Predicted  18716.211541  6805.152986  34734.609884  36655.470016
# Original   16085.127500  3292.529850  41919.097000  44260.749900
#
#                     4            5            6           7            8    \
# Predicted  12337.599345  9781.529387  5491.432738  8926.74842  4812.481159
# Original    9866.304850  8827.209900  2219.445100  7726.85400  2362.229050
#
#                    9    ...          383          384           385  \
# Predicted  7800.806831  ...  9722.574309   427.634295  14864.071384
# Original   4738.268200  ...  9861.025000  1704.700150   9504.310300
#
#                    386           387           388           389  \
# Predicted  5651.551458  33091.826738  10740.511753  11363.584715
# Original   2899.489350  42112.235600  10355.641000  11082.577200
#
#                     390           391         392
# Predicted  27704.025715  15244.329202  8463.06242
# ...
